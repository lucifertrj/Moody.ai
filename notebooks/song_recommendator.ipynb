# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/spotify_songs.csv")

# %%
data.sample(10)
# Out:
#                                name  \
# 601                      Used to Be
# 71                             Blow
# 615  Waiting On the World to Change
# 162               Edge of Seventeen
# 287                      Keep Going
# 549                     The Dreamer
# 285           Kangaroo (Remastered)
# 574                        Time Out
# 181           Fantasy - R3HAB Remix
# 383                    Nowhere Kids
#
#                                                album            artist  \
# 601                                       Used to Be           Jurrivh
# 71                                              Blow            Yves V
# 615                                        Continuum        John Mayer
# 162  Crystal Visions...The Very Best of Stevie Nicks      Stevie Nicks
# 287                                       Keep Going        Mark Milan
# 549                                      The Dreamer      Charles Bolt
# 285                  It'll End In Tears (Remastered)  This Mortal Coil
# 574                                         Time Out             Amoll
# 181                            Fantasy (R3HAB Remix)      Sofie Tukker
# 383                                     Shapeshifter  Smile Empty Soul
#
#                          id release_date  popularity  length  danceability  \
# 601  0p44zFo2S1c50vmx0B7mPF   2020-06-20          38  265641         0.201
# 71   4nX11Rjdh7AuM8Ezb73m1R   2017-05-15           0  165000         0.603
# 615  5imShWWzwqfAJ9gXFpGAQh   2006-09-11          74  201173         0.577
# 162  2id8E4WvczfKHB4LHI7Np3   2007-03-27          70  329680         0.590
# 287  4Hhup3YZfajcC7O0DNbwCq   2019-12-20          31  200527         0.385
# 549  3XnQ3OqmfvP5Sh6gACEKnG   2020-03-19          55  178148         0.235
# 285  1HdIqEOl9MxoJNsz33VOvW         1984          47  209093         0.190
# 574  4CYsf9MUjowxTMTVT39hTL   2020-01-03          32  174240         0.695
# 181  3iGMErA58MMTYT1mBkUkRf   2019-04-19          19  188346         0.700
# 383  08EI81e55Lcqg2ZelJOXcG   2016-04-01          36  248413         0.511
#
#      acousticness  energy  instrumentalness  liveness  valence  loudness  \
# 601      0.989000  0.0394          0.839000    0.0881   0.0754   -21.798
# 71       0.018600  0.9020          0.683000    0.1050   0.1350    -5.979
# 615      0.159000  0.7560          0.000232    0.2490   0.6630    -5.820
# 162      0.277000  0.8280          0.000006    0.0868   0.6360    -6.280
# 287      0.994000  0.3050          0.949000    0.1090   0.1720   -12.044
# 549      0.983000  0.0363          0.920000    0.0823   0.0481   -18.900
# 285      0.768000  0.1670          0.164000    0.1260   0.0491   -11.298
# 574      0.988000  0.0761          0.929000    0.1330   0.2620   -17.043
# 181      0.113000  0.7510          0.001290    0.2410   0.2460    -3.853
# 383      0.000106  0.9140          0.000970    0.1950   0.3930    -5.310
#
#      speechiness    tempo  key  time_signature       mood
# 601       0.0334   73.742   10               4       Calm
# 71        0.0494  127.973    5               4      Happy
# 615       0.1150  176.750    2               4      Happy
# 162       0.0439  111.353    0               4      Happy
# 287       0.0466   74.024    3               4       Calm
# 549       0.0335  160.704    0               5       Calm
# 285       0.0291  169.636    3               4        Sad
# 574       0.0399  125.017    9               4       Calm
# 181       0.0566  124.027    4               4  Energetic
# 383       0.0457   99.011    8               4  Energetic

# %%
data.shape
# Out:
# (686, 19)

# %%
data.mood.unique()
# Out:
# array(['Happy', 'Sad', 'Energetic', 'Calm'], dtype=object)

# %%
mapping = {"Energetic":"Fear","Calm":"Neutral","Happy":"Happy","Sad":"Sad"}

# %%
data.mood = data.mood.map(mapping)

# %%
data.mood
# Out:
# 0        Happy
# 1          Sad
# 2          Sad
# 3        Happy
# 4         Fear
#         ...
# 681    Neutral
# 682        Sad
# 683        Sad
# 684        Sad
# 685    Neutral
# Name: mood, Length: 686, dtype: object

# %%
data.mood.unique()
# Out:
# array(['Happy', 'Sad', 'Fear', 'Neutral'], dtype=object)
